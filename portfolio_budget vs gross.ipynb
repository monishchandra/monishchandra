# %%
import pandas as pd
import seaborn as sns
import numpy as np

import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure
# %matplotlib inline

# %%
df=pd.read_csv('/Users/monishchandra/downloads/movies.csv')

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
df.fillna(0, inplace=True)
for col in df.columns:
    missing=np.mean(df[col].isnull())
    print(f'{col} - {missing}%')
# Out:
# name - 0.0%
# rating - 0.0%
# genre - 0.0%
# year - 0.0%
# released - 0.0%
# score - 0.0%
# votes - 0.0%
# director - 0.0%
# writer - 0.0%
# star - 0.0%
# country - 0.0%
# budget - 0.0%
# gross - 0.0%
# company - 0.0%
# runtime - 0.0%

# %%
df.dtypes['budget']
# Out:
# dtype('float64')

# %%
df['budget']=df['budget'].astype('Int64')
df['gross']=df['gross'].astype('Int64')
df['votes']=df['votes'].astype('Int64')

# %%
##df.head(200)

# %%
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life      0      Drama  2020
# 7664                                     Dream Round      0     Comedy  2020
# 7665                                   Saving Mbango      0      Drama  2020
# 7666                                    It's Just Us      0      Drama  2020
# 7667                                       Tee em el      0     Horror  2020
#
# ...

# %%
##pd.set_option('display.max_rows',4)

# %%
##df.sort_values(by=['score'],inplace=False,ascending= False)

# %%
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes         Int64
# director     object
# writer       object
# star         object
# country      object
# budget        Int64
# gross         Int64
# company      object
# runtime     float64
# dtype: object

# %%
df['released'].astype(str)
# Out:
# 0          June 13, 1980 (United States)
# 1           July 2, 1980 (United States)
# 2          June 20, 1980 (United States)
# 3           July 2, 1980 (United States)
# 4          July 25, 1980 (United States)
#                       ...
# 7663    October 23, 2020 (United States)
# 7664    February 7, 2020 (United States)
# 7665           April 27, 2020 (Cameroon)
# 7666     October 1, 2020 (United States)
# 7667     August 19, 2020 (United States)
# Name: released, Length: 7668, dtype: object

# %%
new_date= df['released'].str.rsplit(' ',n=4,expand=True)

# %%
new_date.rename(columns={0:'month',1:'day',2:'year'},inplace=True)

# %%
df['crt_year']=new_date['year']

# %%
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life      0      Drama  2020
# 7664                                     Dream Round      0     Comedy  2020
# 7665                                   Saving Mbango      0      Drama  2020
# 7666                                    It's Just Us      0      Drama  2020
# 7667                                       Tee em el      0     Horror  2020
#
# ...

# %%
df['gross'] = pd.to_numeric(df['gross'], errors='coerce')
df['budget'] = pd.to_numeric(df['budget'], errors='coerce')

# %%
df['budget']
# Out:
# 0       19000000
# 1        4500000
# 2       18000000
# 3        3500000
# 4        6000000
#           ...
# 7663        7000
# 7664           0
# 7665       58750
# 7666       15000
# 7667           0
# Name: budget, Length: 7668, dtype: Int64

# %%
##pd.set_option('display.max_rows',None)

# %%
df['budget']
# Out:
# 0       19000000
# 1        4500000
# 2       18000000
# 3        3500000
# 4        6000000
#           ...
# 7663        7000
# 7664           0
# 7665       58750
# 7666       15000
# 7667           0
# Name: budget, Length: 7668, dtype: Int64

# %%
##df.fillna(0, inplace=True)

# %%
df['budget']
# Out:
# 0       19000000
# 1        4500000
# 2       18000000
# 3        3500000
# 4        6000000
#           ...
# 7663        7000
# 7664           0
# 7665       58750
# 7666       15000
# 7667           0
# Name: budget, Length: 7668, dtype: Int64

# %%
plt.scatter(x= df['budget'], y=df['gross'])
plt.rcParams['figure.figsize']=(15,9)

# %%
plt.rcParams['figure.figsize']=(15,9)

# %%
plt.scatter(x= df['budget'], y=df['gross'])

# %%
##sns.regplot(x='budget',y='gross',data=df, scatter_kws={"color":'blue'},line_kws={'color':'red'})

# %%
df.corr()
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.092616  0.222427  0.309212  0.261900  0.116358
# score    0.092616  1.000000  0.407101  0.056863  0.186012  0.394564
# votes    0.222427  0.407101  1.000000  0.486931  0.632870  0.306984
# budget   0.309212  0.056863  0.486931  1.000000  0.750157  0.268372
# gross    0.261900  0.186012  0.632870  0.750157  1.000000  0.244339
# runtime  0.116358  0.394564  0.306984  0.268372  0.244339  1.000000

# %%
corr_matrix=df.corr(method='pearson')

# %%
sns.heatmap(corr_matrix, annot=True)
plt.title('Heat map of correlation matrix')
plt.xlabel('Movie features')
plt.ylabel('budget')
# Out:
# Text(114.0, 0.5, 'budget')

# %%
sns.heatmap(corr_matrix, annot=True)
plt.title('Heat map of correlation matrix')
plt.xlabel('Movie features')
plt.ylabel('Movie features')
# Out:
# Text(114.0, 0.5, 'Movie features')

# %%
corr_matrix=df.corr(method='kendall')
sns.heatmap(corr_matrix, annot=True)
plt.title('Heat map of correlation matrix')
plt.xlabel('Movie features')
plt.ylabel('Movie features')
# Out:
# Text(114.0, 0.5, 'Movie features')

# %%
corr_matrix=df.corr(method='spearman')
sns.heatmap(corr_matrix, annot=True)
plt.title('Heat map of correlation matrix')
plt.xlabel('Movie features')
plt.ylabel('Movie features')
# Out:
# Text(114.0, 0.5, 'Movie features')

# %%
df_numerized=df
for col_name in df_numerized.columns:
    if (df_numerized[col_name].dtype == 'object'):
        df_numerized[col_name]= df_numerized[col_name].astype('category')
        df_numerized[col_name]=df_numerized[col_name].cat.codes
df_numerized
# Out:
#       name  rating  genre  year  released  score    votes  director  writer  \
# 0     6587       7      6  1980      1706    8.4   927000      2589    4015
# 1     5573       7      1  1980      1493    5.8    65000      2269    1633
# 2     5142       5      0  1980      1772    8.7  1200000      1111    2568
# 3      286       5      4  1980      1493    7.7   221000      1301    2001
# 4     1027       7      4  1980      1544    7.3   108000      1054     522
# ...    ...     ...    ...   ...       ...    ...      ...       ...     ...
# 7663  3705       0      6  2020      2965    3.1       18      1500    2290
# 7664  1678       0      4  2020      1108    4.7       36       774    2615
# 7665  4717       0      6  2020       194    5.7       29      2061    2684
# 7666  2843       0      6  2020      2818    0.0        0      1184    1825
# 7667  5394       0     10  2020       392    5.7        7      2165    3345
#
# ...

# %%
df_numerized.corr(method='pearson')
# Out:
#               name    rating     genre      year  released     score  \
# name      1.000000 -0.008069  0.016355  0.011453 -0.011311  0.016377
# rating   -0.008069  1.000000  0.072423  0.008779  0.016613  0.006192
# genre     0.016355  0.072423  1.000000 -0.081261  0.029822  0.027384
# year      0.011453  0.008779 -0.081261  1.000000 -0.000695  0.092616
# released -0.011311  0.016613  0.029822 -0.000695  1.000000  0.039814
# score     0.016377  0.006192  0.027384  0.092616  0.039814  1.000000
# votes     0.013038  0.033743 -0.145296  0.222427  0.015878  0.407101
# director  0.009079  0.019483 -0.015258 -0.020795 -0.001478  0.010568
# writer    0.009081 -0.005921  0.006567 -0.008656 -0.002404  0.022098
# star      0.006472  0.013405 -0.005477 -0.027242  0.015777 -0.000026
# country  -0.010737  0.081244 -0.037615 -0.070938 -0.020427 -0.133346
# budget    0.020548 -0.081939 -0.334021  0.309212  0.009145  0.056863
# gross     0.006989 -0.095450 -0.234297  0.261900  0.000519  0.186012
# ...

# %%
sns.heatmap(df_numerized.corr(method='pearson'), annot=True)
plt.title('Heat map of numerized correlation matrix')
plt.xlabel('Movie features')
plt.ylabel('Movie features')
# Out:
# Text(113.59375, 0.5, 'Movie features')

# %%
sorted_pairs=df_numerized.corr().unstack().sort_values()
sorted_pairs
# Out:
# budget    genre      -0.334021
# genre     budget     -0.334021
#           gross      -0.234297
# gross     genre      -0.234297
# genre     votes      -0.145296
#                         ...
# year      year        1.000000
# genre     genre       1.000000
# rating    rating      1.000000
# runtime   runtime     1.000000
# crt_year  crt_year    1.000000
# Length: 256, dtype: float64

# %%
high_corr=sorted_pairs[(sorted_pairs>0.50)]

# %%
high_corr
# Out:
# gross     votes       0.632870
# votes     gross       0.632870
# gross     budget      0.750157
# budget    gross       0.750157
# year      crt_year    0.989057
# crt_year  year        0.989057
# name      name        1.000000
# company   company     1.000000
# gross     gross       1.000000
# budget    budget      1.000000
# country   country     1.000000
# star      star        1.000000
# writer    writer      1.000000
# director  director    1.000000
# votes     votes       1.000000
# score     score       1.000000
# released  released    1.000000
# year      year        1.000000
# genre     genre       1.000000
# rating    rating      1.000000
# runtime   runtime     1.000000
# crt_year  crt_year    1.000000
# dtype: float64

# %%
fig = plt.figure(figsize=(12,8))

plt.subplot(2,2,1)
plt.title('corr_pearson,  subplot: 121')
sns.heatmap(df.corr(method='pearson'), annot=True,square=True, cmap = 'Reds_r')

plt.subplot(2,2,2)
plt.title('corr_kendall,  subplot: 122')          
sns.heatmap(df.corr(method='kendall'), annot=True,square=True, cmap = 'Blues_r')

plt.subplot(2,2,3)
plt.title('corr_spearman,  subplot: 211')
sns.heatmap(df.corr(method='spearman'), annot=True,square=True, cmap = 'Greens_r')


plt.show()

# %%
fig = plt.figure(figsize=(12,8))

plt.subplot(1,2,1)
plt.title('corr_pearson,  subplot:121')
sns.heatmap(df.corr(method='pearson'), annot=True,square=True, cmap = 'Reds_r')
# Out:
# <AxesSubplot:title={'center':'corr_pearson,  subplot:121'}>

# %%
fig = plt.figure(figsize=(12,8))
plt.subplot(122)
plt.title('corr_kendall,  subplot: 122')          
sns.heatmap(df.corr(method='kendall'), annot=True,square=True, cmap = 'Blues_r')
# Out:
# <AxesSubplot:title={'center':'corr_kendall,  subplot: 122'}>
